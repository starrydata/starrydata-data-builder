# %%
import re
import json
import ast

import pandas as pd
from tqdm import tqdm
import numpy as np

# %%
df = pd.read_csv('../data/raw/all_samples.csv', engine='python')

# %%
# Out:
#                                              sample_name  sample_id  \
# 0                                          Pb1Te1I0.0006          1
# 1                                     Pb1Te0.9945I0.0055          2
# 2                                  In0.01Ag0.01Sn0.98Te1          3
# 3                                       Pb1.001Te1I0.002          4
# 4                                     Pb1Te0.9988I0.0012          5
# ...                                                  ...        ...
# 66074                                     AM-Li-4|NCM811      66222
# 66075           (La0.85Sr0.15)sCoO3-delta s=0.98 (Fig 2)      66223
# 66076           (La0.85Sr0.15)sCoO3-delta s=1.00 (Fig 2)      66224
# 66077  La0.7Sr0.3Sc0.8Ti0.2O2.95 in D2O moisturised a...      66225
# 66078  La0.7Sr0.3Sc0.8Ti0.2O2.95 in H2O moisturised a...      66226
#
#                      composition    SID                            DOI  \
# 0                  Pb1Te1I0.0006   4419    10.1016/j.physb.2005.03.022
# ...

# %%
df[' Measurement temperature'].notna().mean()
# Out:
# 0.03961924363262156
