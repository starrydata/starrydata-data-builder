# %%
import re
import json
import ast

import pandas as pd
from tqdm import tqdm
import numpy as np

# %%
df = pd.read_json('/Users/tomoyamato/Documents/starrydb.paperlist_paper.json')

# %%
df
# Out:
#                                         _id                            DOI  \
# 0      {'$oid': '599a9700b036dfb17bdd3193'}              10.1021/ar400290f
# 1      {'$oid': '599a9701b036dfb17bdd3194'}              10.1021/am100654p
# 2      {'$oid': '599a9702b036dfb17bdd3195'}              10.1021/am3002764
# 3      {'$oid': '599a9704b036dfb17bdd3196'}              10.1021/am401444w
# 4      {'$oid': '599a9705b036dfb17bdd3197'}              10.1021/am405035z
# ...                                     ...                            ...
# 46021  {'$oid': '64816a8d97c63367f75e3d30'}      10.1016/j.ssi.2003.12.006
# 46022  {'$oid': '648171d797c63367f5401ed5'}             10.1039/d2ta00119e
# 46023  {'$oid': '648177a997c63367f5401ef9'}      10.1007/s10832-004-5197-5
# 46024  {'$oid': '648181f497c63367f69cd616'}  10.1016/s0167-2738(03)00255-8
# 46025  {'$oid': '64818bb997c63367f75e3d82'}  10.1016/s0167-2738(02)00766-x
#
#        is_referenced_by_count  \
# 0                        29.0
# ...

# %%
df[' Measurement temperature'].notna().mean()
# Out:
# 0.03961924363262156
